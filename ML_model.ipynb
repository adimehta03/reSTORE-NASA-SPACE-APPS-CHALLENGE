# %%
import pandas as pd
import numpy as np
from kmodes.kprototypes import KPrototypes

# %%
df = pd.read_csv('dataset.txt',sep=";")
df
# Out:
#                   plant                         pollutant  cost range  \
# 0             SweetFlag                          Methanol         200
# 1           RedAmarnath                        Napthalene         200
# 2           RedAmarnath                      Phenanthrene         200
# 3      Evergreen azalea                           Toluene         400
# 4         bougainvillea                            Xylene         200
# 5   beach morning glory                          Methanol         500
# 6               vetiver                           Benzene          60
# 7               vetiver                           Toluene          60
# 8               vetiver                      Ethylbenzene          60
# 9               vetiver                            Xylene          60
# 10    Asian pigeonwings                      Formaldehyde         200
# 11       water hyacinth                          Methanol         100
# 12             cucumber                           Alkanes         150
# 13      treasure flower                           alkanes         500
# 14              Jasmine                        Napthalene         410
# 15              Jasmine                      Phenanthrene         410
# 16             Hibiscus                        Napthalene         200
# 17             Hibiscus                        Napthalene         200
# 18      jungle geranium                        Napthalene         160
# 19      jungle geranium                      Phenanthrene         160
# 20      jungle geranium  Polycyclic Aromatic Hydrocarbons         160
# 21          English Ivy                Particulate matter         750
# 22             RyeGrass            Petroleum Hydrocarbons          50
# 23             RyeGrass                      Phenanthrene          50
# 24          hoary stock                           Alkanes         150
# 25                 rice                          Methanol         150
# 26          common bean                         crude oil         200
# 27          common bean                      Phenanthrene         200
# 28          common bean                        Octadexane         200
# 29                  pea          Polyaromatic hydrocarbon         120
# 30         yellow elder                           Alkanes         350
# 31      glaucous willow  Polycyclic Aromatic Hydrocarbons         600
# 32   purpleosier willow  Polycyclic Aromatic Hydrocarbons         300
# 33                Dandy                           Alkanes         100
# 34       Trumpet Flower             Volatile Hydrocarbons         250
# 35       Trumpet Flower                           Alkanes         250
# 36            broadbean                           Alkanes         200
# 37            broadbean                      Phenanthrene         200
# 38            broadbean                         Crude oil         200
# 39            broadbean                        Hexadecane         200
#
#    Moisture Temperature
# 0      High         Low
# 1    Normal      Normal
# 2    Normal      Normal
# 3       Low         Low
# 4      High      Normal
# 5    Normal        High
# 6    Normal      Normal
# 7    Normal      Normal
# 8    Normal      Normal
# 9    Normal      Normal
# 10     High      Normal
# 11     High         Low
# 12     High      Normal
# 13      Low        High
# 14      Low      Normal
# 15      Low      Normal
# 16     High         Low
# 17     High         Low
# 18     High      Normal
# 19     High      Normal
# 20     High      Normal
# 21      Low         Low
# 22     High      Normal
# 23     High      Normal
# 24   Normal         Low
# 25     High      Normal
# 26     High      Normal
# 27     High      Normal
# 28     High      Normal
# 29     High      Normal
# 30   Normal        High
# 31     High      Normal
# 32     High      Normal
# 33      Low        High
# 34      Low      Normal
# 35      Low      Normal
# 36   Normal      Normal
# 37   Normal      Normal
# 38   Normal      Normal
# 39   Normal      Normal

# %%
df['pollutant'].unique()
# Out:
# array(['Methanol', 'Napthalene', 'Phenanthrene', 'Toluene', 'Xylene',
#        'Benzene', 'Ethylbenzene', 'Formaldehyde', 'Alkanes', 'alkanes',
#        'Polycyclic Aromatic Hydrocarbons', 'Particulate matter',
#        'Petroleum Hydrocarbons', 'crude oil', 'Octadexane',
#        'Polyaromatic hydrocarbon', 'Volatile Hydrocarbons', 'Crude oil',
#        'Hexadecane'], dtype=object)

# %%
df['Temperature'].unique(),df['Moisture'].unique()
# Out:
# (array(['Low', 'Normal', 'High'], dtype=object),
#  array(['High', 'Normal', 'Low'], dtype=object))

# %%
pollutants = list(df['pollutant'])
pollutants
# for i in pollutants:
# Out:
# ['Methanol',
#  'Napthalene',
#  'Phenanthrene',
#  'Toluene',
#  'Xylene',
#  'Methanol',
#  'Benzene',
#  'Toluene',
#  'Ethylbenzene',
#  'Xylene',
#  'Formaldehyde',
#  'Methanol',
#  'Alkanes',
#  'alkanes',
#  'Napthalene',
#  'Phenanthrene',
#  'Napthalene',
#  'Napthalene',
#  'Napthalene',
#  'Phenanthrene',
#  'Polycyclic Aromatic Hydrocarbons',
#  'Particulate matter',
#  'Petroleum Hydrocarbons',
#  'Phenanthrene',
#  'Alkanes',
#  'Methanol',
#  'crude oil',
#  'Phenanthrene',
#  'Octadexane',
#  'Polyaromatic hydrocarbon',
#  'Alkanes',
#  'Polycyclic Aromatic Hydrocarbons',
#  'Polycyclic Aromatic Hydrocarbons',
#  'Alkanes',
#  'Volatile Hydrocarbons',
#  'Alkanes',
#  'Alkanes',
#  'Phenanthrene',
#  'Crude oil',
#  'Hexadecane']

# %%
df_array = df.values

df_array[:, 2] = df_array[:, 2].astype(float)

df_array
# Out:
# array([['SweetFlag', 'Methanol', 200.0, 'High', 'Low'],
#        ['RedAmarnath', 'Napthalene', 200.0, 'Normal', 'Normal'],
#        ['RedAmarnath', 'Phenanthrene', 200.0, 'Normal', 'Normal'],
#        ['Evergreen azalea', 'Toluene', 400.0, 'Low', 'Low'],
#        ['bougainvillea', 'Xylene', 200.0, 'High', 'Normal'],
#        ['beach morning glory', 'Methanol', 500.0, 'Normal', 'High'],
#        ['vetiver', 'Benzene', 60.0, 'Normal', 'Normal'],
#        ['vetiver', 'Toluene', 60.0, 'Normal', 'Normal'],
#        ['vetiver', 'Ethylbenzene', 60.0, 'Normal', 'Normal'],
#        ['vetiver', 'Xylene', 60.0, 'Normal', 'Normal'],
#        ['Asian pigeonwings', 'Formaldehyde', 200.0, 'High', 'Normal'],
#        ['water hyacinth', 'Methanol', 100.0, 'High', 'Low'],
#        ['cucumber', 'Alkanes', 150.0, 'High', 'Normal'],
#        ['treasure flower', 'alkanes', 500.0, 'Low', 'High'],
#        ['Jasmine', 'Napthalene', 410.0, 'Low', 'Normal'],
#        ['Jasmine', 'Phenanthrene', 410.0, 'Low', 'Normal'],
#        ['Hibiscus', 'Napthalene', 200.0, 'High', 'Low'],
#        ['Hibiscus', 'Napthalene', 200.0, 'High', 'Low'],
#        ['jungle geranium', 'Napthalene', 160.0, 'High', 'Normal'],
#        ['jungle geranium', 'Phenanthrene', 160.0, 'High', 'Normal'],
#        ['jungle geranium', 'Polycyclic Aromatic Hydrocarbons', 160.0,
#         'High', 'Normal'],
#        ['English Ivy', 'Particulate matter', 750.0, 'Low', 'Low'],
#        ['RyeGrass', 'Petroleum Hydrocarbons', 50.0, 'High', 'Normal'],
#        ['RyeGrass', 'Phenanthrene', 50.0, 'High', 'Normal'],
#        ['hoary stock', 'Alkanes', 150.0, 'Normal', 'Low'],
#        ['rice', 'Methanol', 150.0, 'High', 'Normal'],
#        ['common bean', 'crude oil', 200.0, 'High', 'Normal'],
#        ['common bean', 'Phenanthrene', 200.0, 'High', 'Normal'],
#        ['common bean', 'Octadexane', 200.0, 'High', 'Normal'],
#        ['pea', 'Polyaromatic hydrocarbon', 120.0, 'High', 'Normal'],
#        ['yellow elder', 'Alkanes', 350.0, 'Normal', 'High'],
#        ['glaucous willow', 'Polycyclic Aromatic Hydrocarbons', 600.0,
#         'High', 'Normal'],
#        ['purpleosier willow', 'Polycyclic Aromatic Hydrocarbons', 300.0,
#         'High', 'Normal'],
#        ['Dandy', 'Alkanes', 100.0, 'Low', 'High'],
#        ['Trumpet Flower', 'Volatile Hydrocarbons', 250.0, 'Low',
#         'Normal'],
#        ['Trumpet Flower', 'Alkanes', 250.0, 'Low', 'Normal'],
#        ['broadbean', 'Alkanes', 200.0, 'Normal', 'Normal'],
#        ['broadbean', 'Phenanthrene', 200.0, 'Normal', 'Normal'],
#        ['broadbean', 'Crude oil', 200.0, 'Normal', 'Normal'],
#        ['broadbean', 'Hexadecane', 200.0, 'Normal', 'Normal']],
#       dtype=object)

# %%
kproto = KPrototypes(n_clusters=3, verbose=2,max_iter=20)
clusters = kproto.fit_predict(df_array, categorical=[0,1,3,4])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 6, ncost: 160570.51693451017
# Run: 1, iteration: 2/20, moves: 1, ncost: 159936.73791905912
# Run: 1, iteration: 3/20, moves: 0, ncost: 159936.73791905912
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 16, ncost: 164006.74242170525
# Run: 2, iteration: 2/20, moves: 1, ncost: 159936.73791905912
# Run: 2, iteration: 3/20, moves: 0, ncost: 159936.73791905912
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 3, ncost: 170139.97299852408
# Run: 3, iteration: 2/20, moves: 0, ncost: 170139.97299852408
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 17, ncost: 164006.74242170525
# Run: 4, iteration: 2/20, moves: 1, ncost: 159936.73791905915
# Run: 4, iteration: 3/20, moves: 0, ncost: 159936.73791905915
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 2, ncost: 159936.73791905915
# Run: 5, iteration: 2/20, moves: 0, ncost: 159936.73791905915
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 14, ncost: 341955.3706702444
# Run: 6, iteration: 2/20, moves: 12, ncost: 159936.73791905912
# Run: 6, iteration: 3/20, moves: 0, ncost: 159936.73791905912
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 4, ncost: 159936.73791905915
# Run: 7, iteration: 2/20, moves: 0, ncost: 159936.73791905915
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 0, ncost: 159936.73791905915
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 16, ncost: 164006.74242170525
# Run: 9, iteration: 2/20, moves: 1, ncost: 159936.73791905912
# Run: 9, iteration: 3/20, moves: 0, ncost: 159936.73791905912
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 3, ncost: 170139.97299852408
# Run: 10, iteration: 2/20, moves: 0, ncost: 170139.97299852408
# Best run was number 1

# %%
print(kproto.cluster_centroids_)
# Out:
# [array([[ 73.33333333],
#        [196.95652174],
#        [490.        ]]), array([['vetiver', 'Alkanes', 'High', 'Normal'],
#        ['broadbean', 'Napthalene', 'High', 'Normal'],
#        ['Jasmine', 'Alkanes', 'Low', 'High']], dtype='<U10')]

# %%
cluster_dict=[]
for c in clusters:
    cluster_dict.append(c)

# %%
cluster_dict
# Out:
# [1,
#  1,
#  1,
#  2,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  1,
#  0,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  0,
#  0,
#  1,
#  1,
#  1,
#  1,
#  1,
#  0,
#  2,
#  2,
#  1,
#  0,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1]

# %%
df['cluster'] = cluster_dict
df
# Out:
#                   plant                         pollutant  cost range  \
# 0             SweetFlag                          Methanol         200
# 1           RedAmarnath                        Napthalene         200
# 2           RedAmarnath                      Phenanthrene         200
# 3      Evergreen azalea                           Toluene         400
# 4         bougainvillea                            Xylene         200
# 5   beach morning glory                          Methanol         500
# 6               vetiver                           Benzene          60
# 7               vetiver                           Toluene          60
# 8               vetiver                      Ethylbenzene          60
# 9               vetiver                            Xylene          60
# 10    Asian pigeonwings                      Formaldehyde         200
# 11       water hyacinth                          Methanol         100
# 12             cucumber                           Alkanes         150
# 13      treasure flower                           alkanes         500
# 14              Jasmine                        Napthalene         410
# 15              Jasmine                      Phenanthrene         410
# 16             Hibiscus                        Napthalene         200
# 17             Hibiscus                        Napthalene         200
# 18      jungle geranium                        Napthalene         160
# 19      jungle geranium                      Phenanthrene         160
# 20      jungle geranium  Polycyclic Aromatic Hydrocarbons         160
# 21          English Ivy                Particulate matter         750
# 22             RyeGrass            Petroleum Hydrocarbons          50
# 23             RyeGrass                      Phenanthrene          50
# 24          hoary stock                           Alkanes         150
# 25                 rice                          Methanol         150
# 26          common bean                         crude oil         200
# 27          common bean                      Phenanthrene         200
# 28          common bean                        Octadexane         200
# 29                  pea          Polyaromatic hydrocarbon         120
# 30         yellow elder                           Alkanes         350
# 31      glaucous willow  Polycyclic Aromatic Hydrocarbons         600
# 32   purpleosier willow  Polycyclic Aromatic Hydrocarbons         300
# 33                Dandy                           Alkanes         100
# 34       Trumpet Flower             Volatile Hydrocarbons         250
# 35       Trumpet Flower                           Alkanes         250
# 36            broadbean                           Alkanes         200
# 37            broadbean                      Phenanthrene         200
# 38            broadbean                         Crude oil         200
# 39            broadbean                        Hexadecane         200
#
#    Moisture Temperature  cluster
# 0      High         Low        1
# 1    Normal      Normal        1
# 2    Normal      Normal        1
# 3       Low         Low        2
# 4      High      Normal        1
# 5    Normal        High        2
# 6    Normal      Normal        0
# 7    Normal      Normal        0
# 8    Normal      Normal        0
# 9    Normal      Normal        0
# 10     High      Normal        1
# 11     High         Low        0
# 12     High      Normal        1
# 13      Low        High        2
# 14      Low      Normal        2
# 15      Low      Normal        2
# 16     High         Low        1
# 17     High         Low        1
# 18     High      Normal        1
# 19     High      Normal        1
# 20     High      Normal        1
# 21      Low         Low        2
# 22     High      Normal        0
# 23     High      Normal        0
# 24   Normal         Low        1
# 25     High      Normal        1
# 26     High      Normal        1
# 27     High      Normal        1
# 28     High      Normal        1
# 29     High      Normal        0
# 30   Normal        High        2
# 31     High      Normal        2
# 32     High      Normal        1
# 33      Low        High        0
# 34      Low      Normal        1
# 35      Low      Normal        1
# 36   Normal      Normal        1
# 37   Normal      Normal        1
# 38   Normal      Normal        1
# 39   Normal      Normal        1

# %%
df[df['cluster']== 0].head(10)
# Out:
#              plant                 pollutant  cost range Moisture Temperature  \
# 6          vetiver                   Benzene          60   Normal      Normal
# 7          vetiver                   Toluene          60   Normal      Normal
# 8          vetiver              Ethylbenzene          60   Normal      Normal
# 9          vetiver                    Xylene          60   Normal      Normal
# 11  water hyacinth                  Methanol         100     High         Low
# 22        RyeGrass    Petroleum Hydrocarbons          50     High      Normal
# 23        RyeGrass              Phenanthrene          50     High      Normal
# 29             pea  Polyaromatic hydrocarbon         120     High      Normal
# 33           Dandy                   Alkanes         100      Low        High
#
#     cluster
# 6         0
# 7         0
# 8         0
# 9         0
# 11        0
# 22        0
# 23        0
# 29        0
# 33        0

# %%
df[df['cluster']== 1].head(10)
# Out:
#                 plant     pollutant  cost range Moisture Temperature  cluster
# 0           SweetFlag      Methanol         200     High         Low        1
# 1         RedAmarnath    Napthalene         200   Normal      Normal        1
# 2         RedAmarnath  Phenanthrene         200   Normal      Normal        1
# 4       bougainvillea        Xylene         200     High      Normal        1
# 10  Asian pigeonwings  Formaldehyde         200     High      Normal        1
# 12           cucumber       Alkanes         150     High      Normal        1
# 16           Hibiscus    Napthalene         200     High         Low        1
# 17           Hibiscus    Napthalene         200     High         Low        1
# 18    jungle geranium    Napthalene         160     High      Normal        1
# 19    jungle geranium  Phenanthrene         160     High      Normal        1

# %%
df[df['cluster']== 2].head(10)
# Out:
#                   plant                         pollutant  cost range  \
# 3      Evergreen azalea                           Toluene         400
# 5   beach morning glory                          Methanol         500
# 13      treasure flower                           alkanes         500
# 14              Jasmine                        Napthalene         410
# 15              Jasmine                      Phenanthrene         410
# 21          English Ivy                Particulate matter         750
# 30         yellow elder                           Alkanes         350
# 31      glaucous willow  Polycyclic Aromatic Hydrocarbons         600
#
#    Moisture Temperature  cluster
# 3       Low         Low        2
# 5    Normal        High        2
# 13      Low        High        2
# 14      Low      Normal        2
# 15      Low      Normal        2
# 21      Low         Low        2
# 30   Normal        High        2
# 31     High      Normal        2
